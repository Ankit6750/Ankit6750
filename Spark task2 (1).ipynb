# %% [markdown]
# # Ankit Dadarwala
# task:2>>Exploratory Data Analysis on dataset SampleSuperstore

# %% [markdown]
# As a business manager, try to find out the weak areas where you can
# work to make more profit.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
print('Here getting Dataset from link')
df=pd.read_csv('SampleSuperstore.csv')
df.head(10)
# Out:
# Here getting Dataset from link
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# ...

# %%
#Data types
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# Data shape
df.shape
# Out:
# (9994, 13)

# %%
# Information about DATA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# Checking Null values
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# Graphical representaion of null value
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# Finding Duplicate
df.duplicated().sum()
# Out:
# 17

# %%
# REmove Duplicate Rows
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.drop('Postal Code',axis=1,inplace=True)

# %%
df.shape
# Out:
# (9994, 12)

# %%
## Statistical analysis
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# In this Mean is greater the median so data must spread in Sales,profit columns
# High values in Standard deviation skewness present in datas
# max is much higher that 75% of data so too much outliers are present

# %%
df['Sales'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Quantity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Discount'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Profit'].plot.box()
# Out:
# <AxesSubplot:>

# %%
# To check Skewness
df.skew()
# Out:
# Sales       12.972752
# Quantity     1.278545
# Discount     1.684295
# Profit       7.561432
# dtype: float64

# %%
sns.distplot(df['Sales'])
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
sns.distplot(df['Profit'])
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(df['Discount'])
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Density'>

# %%
# REmove Skewness by log transformation
from scipy.stats import boxcox

# %%
df['Sales']=boxcox(df['Sales'],0)

# %%
sns.distplot(df['Sales'])
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
df.skew()
# Out:
# Sales       0.188648
# Quantity    1.278545
# Discount    1.684295
# Profit      7.561432
# dtype: float64

# %%
# Checking Co-relation between columns
df.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.323831 -0.162657  0.200182
# Quantity  0.323831  1.000000  0.008623  0.066253
# Discount -0.162657  0.008623  1.000000 -0.219487
# Profit    0.200182  0.066253 -0.219487  1.000000

# %%
# Graphical Representation
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that profit is negatively co related with discount

# %%
print('No. of segment:',df['Segment'].nunique())
print('No. of Country:',df['Country'].nunique())
print('No. of City:',df['City'].nunique())
print('No. of State:',df['State'].nunique())
print('No. of Region:',df['Region'].nunique())
print('Category of product:',df['Category'].nunique())
print('Sub category of product:',df['Sub-Category'].nunique())
print('No. of Ship mode:',df['Ship Mode'].nunique())
# Out:
# No. of segment: 3
# No. of Country: 1
# No. of City: 531
# No. of State: 49
# No. of Region: 4
# Category of product: 3
# Sub category of product: 17
# No. of Ship mode: 4

# %%
df.groupby('Segment')['Category'].unique()
# Out:
# Segment
# Consumer       [Furniture, Office Supplies, Technology]
# Corporate      [Office Supplies, Technology, Furniture]
# Home Office    [Office Supplies, Furniture, Technology]
# Name: Category, dtype: object

# %%
df.groupby('Category')['Sub-Category'].unique()
# Out:
# Category
# Furniture                   [Bookcases, Chairs, Tables, Furnishings]
# Office Supplies    [Labels, Storage, Art, Binders, Appliances, Pa...
# Technology                  [Phones, Accessories, Machines, Copiers]
# Name: Sub-Category, dtype: object

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# VISUALIZATION OF DATA

# %%
df.groupby('Segment')['Sales','Profit'].sum().plot(kind='bar',figsize=(8,4))
# Out:
# <AxesSubplot:xlabel='Segment'>

# %% [markdown]
# Here most of products consumming by Consumer category customers

# %%
df.groupby('Category')['Sales','Profit','Discount'].sum().sort_values(by='Profit',ascending=False).plot(kind='bar',figsize=(8,4))
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# In category vise Technology department we can get more profit by less selling of products

# %%
df.groupby('Sub-Category')['Sales','Profit','Discount'].sum().sort_values(by='Profit',ascending=False).plot(kind='bar',figsize=(12,10))
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# From that Bar graph we show that too much losses in tables,bookcaes,supplies selling here the area we can work more for profit

# %%
sns.barplot(x='Region',y='Sales',hue='Region',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %% [markdown]
# Maximum sells in West region but less profit in central reion

# %%
sns.barplot(x='Region',y='Profit',hue='Region',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %% [markdown]
# See that tech field has more profit in category

# %%
plt.figure(figsize=(18,10))
sns.countplot(df['Sub-Category'].sort_values(ascending=True))
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='count'>

# %%
sns.pairplot(data=df,hue='Category')

# %%
sns.pairplot(data=df,hue='Sub-Category')

# %%
df['Sub-Category'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(14,12))
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %% [markdown]
# Home office and Furniture has very sales in all region so for improve their selling with different skims that improve profit
# OR also Selling more phones and tech field appliences imporve profit

# %%
df['Region'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(8,6))
# Out:
# <AxesSubplot:ylabel='Region'>

# %% [markdown]
# From that pie plot less saling in South zone region so improve sales at that region for profit

# %%
sns.lineplot(x='Discount',y='Profit',label='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# Here we can show that the discount is negatively affect the profit so we reduce some discount offers for profit or improve sales

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='Category',y='Profit',hue='Quantity',data=df)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Profit'>
